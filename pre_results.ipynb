# %%
from src.analysis.test_analysis import test_trajectory, test_last_window
from src.analysis.plot_analysis import plot_trayectorias_absolutas, plot_trayectorias_error

# %%
test_trajectory(debug=False)
# Out:
# ...
#   SUBANÁLISIS 1 — Métricas globales | Test set completo
# ...
#            Modelo  S-Score  C-Index    MAE    RMSE
#     Random Forest   2.0986   0.9112 7.2835 11.0007
#           XGBoost   2.1273   0.9107 7.3885 10.9865
#               SVR   2.2157   0.9105 6.9808 10.8500
# Negative Binomial   2.4439   0.8938 9.3912 13.6031
#     Decision Tree   2.8704   0.8981 7.7353 12.0904
#
#   Ventanas totales evaluadas: 8163
#   Motores de test:            60
# ...

# %%
test_last_window(debug=False)
# Out:
# ...
#   SUBANÁLISIS 2 — Zona de riesgo | Última ventana por motor
# ...
#            Modelo  S-Score  C-Index    MAE    RMSE
#     Decision Tree   0.6971   0.9562 4.2842  6.4088
#               SVR   0.9011   0.9669 4.7514  6.9164
#           XGBoost   0.9229   0.9621 5.0520  7.3286
#     Random Forest   0.9316   0.9613 4.9285  7.0704
# Negative Binomial   2.0231   0.9444 9.6792 11.8996
#
#   Motores evaluados: 60
# ...

# %%
test_per_motor(debug=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 test_per_motor(debug=False)
#
# NameError: name 'test_per_motor' is not defined

# %%
plot_trayectorias_absolutas(debug=False)

# %%
plot_trayectorias_error(debug=False)
